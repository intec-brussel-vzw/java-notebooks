# %% [markdown]
# # Spring Boot: Ontwikkelaar
#
# > tags: []
# > author:
#
# # Spring Boot: Ontwikkelaar
#
# This 2-day course offers experience with Spring Boot and its major features, including auto-configuration, Actuator, Spring Boot testing framework and more. On completion, participants will have a foundation for creating enterprise and cloud-ready applications.
#
#
# <table><tbody><tr><td _msthash="930124" _msttexthash="222365">Samenvatting:</td><td>&nbsp;</td><td><div><p><a title="Classroom Schedule" alt="Classroom Schedule" href="https://mylearn.vmware.com/portals/www/search/results.cfm?ui=www_edu&amp;menu=search-results&amp;searchtype=simple&amp;category=schedule&amp;id_subject=94108&amp;deliveryType=1&amp;filters=deliveryType"><img src="https://mylearn.vmware.com/ui/images/buttons/en/btnbluelarge_classroom.png" width="145" height="21" alt="Lesrooster" _mstalt="162838"></a></p><p><a title="Live Online Schedule" alt="Live Online Schedule" href="https://mylearn.vmware.com/portals/www/search/results.cfm?ui=www_edu&amp;menu=search-results&amp;searchtype=simple&amp;category=schedule&amp;id_subject=94108&amp;deliveryType=16&amp;filters=deliveryType"><img src="https://mylearn.vmware.com/ui/images/buttons/en/btnbluelarge_live-online.png" width="145" height="21" alt="Live online schema" _mstalt="315653"></a></p><p><a title="vFlex-ILT Schedule" alt="vFlex-ILT Schedule" href="https://mylearn.vmware.com/portals/www/search/results.cfm?ui=www_edu&amp;menu=search-results&amp;searchtype=simple&amp;category=schedule&amp;id_subject=94108&amp;deliveryType=56&amp;filters=deliveryType"><img src="https://mylearn.vmware.com/ui/images/buttons/en/btnbluelarge_vflex-ilt.png" width="145" height="21" alt="vFlex-ILT Schema" _mstalt="253760"></a></p><p><a title="Inquire about Onsite" alt="Inquire about Onsite" href="https://mylearn.vmware.com/mgrReg/onsiteRequest.cfm?ui=www_edu&amp;subject=Onsite%20Training&amp;id_subject=94108"><img src="https://mylearn.vmware.com/ui/images/buttons/en/btnbluelarge_inquire-about-onsite.png" width="145" height="21" alt="Informeer naar Onsite" _mstalt="414479"></a></p><p><a title="Course Datasheet" alt="Course Datasheet" href="https://mylearn.vmware.com/descriptions/EDU_DATASHEET%20Spring%20Boot%20Developer.pdf" target="_blank"><img src="https://mylearn.vmware.com/ui/images/buttons/en/btngraylarge_course-datasheet.png" width="145" height="21" alt="Cursus Datasheet" _mstalt="285792"></a></p></div><p><span _mstmutation="1" _msthash="1228604" _msttexthash="1783964">- Formaten: <strong _mstmutation="1" _istranslated="1">Klaslokaal</strong>, <strong _mstmutation="1" _istranslated="1">Live Online</strong>, <strong _mstmutation="1" _istranslated="1">vFlex-ILT</strong>, <strong _mstmutation="1" _istranslated="1">Onsite</strong></span></p><p>- Duur: 2 dagen</p><div><p><strong _msthash="1567137" _msttexthash="150267">Overzicht:</strong></p><div _msthash="1567280" _msttexthash="240015477"><p>Deze 2-daagse cursus biedt ervaring met Spring Boot en de belangrijkste functies, waaronder automatische configuratie, actuator, spring boot testraamwerk en meer. Na voltooiing hebben de deelnemers een basis voor het maken van bedrijfs- en cloudklare applicaties.</p><p>Houd er rekening mee dat deze cursus een subset is van het materiaal in onze 4-daagse Spring: Core Training-cursus - het is niet nodig om beide cursussen te volgen. Deze cursus wordt aanbevolen als je een goede praktische kennis hebt van Spring Basics (zie Vereisten) maar nieuw bent bij Spring Boot.</p><p>Deze cursus is ook beschikbaar in een On Demand-formaat. Selecteer voor meer informatie deze link: <a href="https://mylearn.vmware.com/mgrReg/courses.cfm?ui=www_edu&amp;a=one&amp;id_subject=96645" _istranslated="1" name="&amp;lpos=apps_scodevmw : 274" onclick="s_objectID='apps_scodevmw : Spring Boot: Developer - On Demand : 274'">Spring Boot: Developer - On Demand</a>.</p></div></div></td></tr><tr><td colspan="3"><hr></td></tr><tr><td _msthash="930514" _msttexthash="275548">Doelstellingen:</td><td>&nbsp;&nbsp;</td><td _msthash="930774" _msttexthash="599385228">Aan het einde van de cursus zou u de volgende doelstellingen moeten kunnen bereiken:<br _istranslated="1">• Beschrijf de voordelen van Spring Boot<br _istranslated="1">• Initialiseer een project met Spring Boot Starters<br _istranslated="1">• Maak gebruik van de automatische configuratiefuncties<br _istranslated="1">van Spring Boot • Maak vereenvoudigde backing-store-oplossingen met Spring Data JPA<br _istranslated="1">• Bouw een eenvoudige MVC-applicatie met Spring Boot, embedded webserver en dikke JARs of klassieke WAV's<br _istranslated="1">• Bouw een RESTful webapplicatie<br _istranslated="1">• Gebruik Spring Boot-verbeteringen om te testen<br _istranslated="1">• Gebruik Spring Security om web- en REST-eindpunten<br _istranslated="1">te beveiligen • Schakel metrische gegevens en bewakingsmogelijkheden in en uit met behulp van Spring Boot-actuator<br _istranslated="1">• Maak gebruik van geavanceerde configuratiemogelijkheden</td></tr><tr><td colspan="3">&nbsp;</td></tr><tr><td nowrap="nowrap" _msthash="930904" _msttexthash="334113">Beoogde doelgroep:</td><td>&nbsp;&nbsp;</td><td _msthash="931164" _msttexthash="8668309">Applicatieontwikkelaars die hun begrip van Spring en Spring Boot willen vergroten en zich willen richten op de fundamenten.</td></tr><tr><td colspan="3">&nbsp;</td></tr><tr><td _msthash="931294" _msttexthash="194857">Voorwaarden:</td><td>&nbsp;&nbsp;</td><td _msthash="931554" _msttexthash="95255355">• Een goede praktische kennis van webapplicatie ontwikkeling met behulp van Java en een IDE (Eclipse, STS of<br _istranslated="1">IntelliJ).<br _istranslated="1">• Basiskennis van Spring: Java Config, component-scanning, Spring driven testing en Spring data-management<br _istranslated="1">(JdbcTemplate, @Transactional).<br _istranslated="1">• Ervaring met het gebruik van Java en het bouwen van tools zoals Maven of Gradle.</td></tr><tr><td colspan="3">&nbsp;</td></tr><tr><td _msthash="931684" _msttexthash="87854">Omtrek:</td><td>&nbsp;&nbsp;</td><td _msthash="931944" _msttexthash="5822050416">1 Inleiding tot Spring Essentials<br _istranslated="1">• Waarom Lente<br _istranslated="1">• Configuratie met behulp van Spring<br _istranslated="1">• Bean creatie<br _istranslated="1">• Data Management<p>2 Spring Boot Introductie<br _istranslated="1">• Inleiding tot Spring Boot Functies<br _istranslated="1">• Waardepropositie van Spring Boot<br _istranslated="1">• Een eenvoudige Boot applicatie maken met behulp van Spring Initializr website</p><p>3 Spring Boot – A Closer Look<br _istranslated="1">• Dependency management met Spring Boot starters<br _istranslated="1">• Hoe automatische configuratie werkt<br _istranslated="1">• Configuratie-eigenschappen<br _istranslated="1">• Automatische configuratie<br _istranslated="1">overschrijven • CommandLineRunner</p><p>4 Spring Boot gebruiken – Spring Data JPA<br _istranslated="1">• Snelle introductie tot ORM met JPA<br _istranslated="1">• Voordelen van het gebruik van Spring met JPA<br _istranslated="1">• JPA-configuratie in de lente<br _istranslated="1">• Spring JPA configureren met Spring Boot<br _istranslated="1">• Spring Data JPA dynamische repositories</p><p>5 webapplicaties met Spring Boot<br _istranslated="1">• Inleiding tot Spring MVC en aanvraagverwerking<br _istranslated="1">• Handtekeningen van controllermethodes<br _istranslated="1">• Gebruik van @Controller, @RestController en @GetMapping annotaties<br _istranslated="1">• Spring MVC configureren met Spring Boot<br _istranslated="1">• Spring Boot verpakkingsopties, JAR of WAR</p><p>6 RESTful Application met Spring Boot<br _istranslated="1">• Een inleiding tot de REST-architectuurstijl<br _istranslated="1">• HTTP-responscodes beheren met @ResponseStatus<br _istranslated="1">• REST implementeren met Spring MVC, @RequestMapping, @RequestBody en @ResponseBody<br _istranslated="1">• Spring MVC's HttpMessageConverters en automatische contentonderhandeling</p><p>7 Spring Boot Testing<br _istranslated="1">• Spring Boot testing overzicht<br _istranslated="1">• Integratie testen met behulp van @SpringBootTest<br _istranslated="1">• Web slice testen met MockMvc framework<br _istranslated="1">• Slices om verschillende lagen van de applicatie</p><p>te testen 8 Rest-applicatie beveiligen met Spring Security<br _istranslated="1">• Welke problemen lost Spring Security op?<br _istranslated="1">• Authenticatie configureren<br _istranslated="1">• Autorisatie implementeren door URL's<br _istranslated="1">te onderscheppen • Autorisatie op Java-methodeniveau<br _istranslated="1">• Inzicht in de Spring Security-filterketen<br _istranslated="1">• Spring-beveiligingstests</p><p>9 actuatoren, metrische gegevens en gezondheidsindicatoren<br _istranslated="1">• Spring Boot Actuator-eindpunten<br _istranslated="1">blootstellen • Aangepaste statistieken • Gezondheidsindicatoren<br _istranslated="1">• Aangepaste gezondheidsindicatoren<br _istranslated="1">maken<br _istranslated="1">• Externe monitoringsystemen</p></td></tr><tr><td colspan="3">&nbsp;</td></tr></tbody></table>
#
# ## [VMware-leren](https://mylearn.vmware.com/mgrReg/index.cfm?ui=www_edu&redirect=off)
#
# -   [Aanmelden](https://mylearn.vmware.com/mgrReg/login.cfm?ui=www_edu)
# -   [Certificering](https://mylearn.vmware.com/portals/certification/)
# -   Training onder leiding van een instructeur
# -   [Privé training](https://mylearn.vmware.com/mgrReg/plan.cfm?plan=38045&ui=www_edu)
# -   Digitale training via Connect Learning
# -   Training per product
# -   Gratis bronnen
# -   Besparingsmogelijkheden
# -   Nieuws & Evenementen
# -   Help
#
# [![VMware-community](https://vmware-vault.s3.amazonaws.com/VMware%20Education%20Page/img/vmwarecommunity.png)](https://communities.vmware.com/community/vmtn/certedu)
#
#
# Aan het einde van de cursus zou u de volgende doelstellingen moeten kunnen bereiken:
# • Beschrijf de voordelen van Spring Boot
# • Initialiseer een project met Spring Boot Starters
# • Maak gebruik van de automatische configuratiefuncties
# van Spring Boot • Maak vereenvoudigde backing-store-oplossingen met Spring Data JPA
# • Bouw een eenvoudige MVC-applicatie met Spring Boot, embedded webserver en dikke JARs of klassieke WAV's
# • Bouw een RESTful webapplicatie
# • Gebruik Spring Boot-verbeteringen om te testen
# • Gebruik Spring Security om web- en REST-eindpunten
# te beveiligen • Schakel metrische gegevens en bewakingsmogelijkheden in en uit met behulp van Spring Boot-actuator
# • Maak gebruik van geavanceerde configuratiemogelijkheden
#
# ## Voorwaarden
#
#
# • Een goede praktische kennis van webapplicatie ontwikkeling met behulp van Java en een IDE (Eclipse, STS of
# IntelliJ).
# • Basiskennis van Spring: Java Config, component-scanning, Spring driven testing en Spring data-management
# (JdbcTemplate, @Transactional).
# • Ervaring met het gebruik van Java en het bouwen van tools zoals Maven of Gradle.
#
#
# ## Inzicht
#
# 1 Inleiding tot Spring Essentials
# • Waarom Lente
# • Configuratie met behulp van Spring
# • Bean creatie
# • Data Management
#
# 2 Spring Boot Introductie
# • Inleiding tot Spring Boot Functies
# • Waardepropositie van Spring Boot
# • Een eenvoudige Boot applicatie maken met behulp van Spring Initializr website
#
# 3 Spring Boot – A Closer Look
# • Dependency management met Spring Boot starters
# • Hoe automatische configuratie werkt
# • Configuratie-eigenschappen
# • Automatische configuratie
# overschrijven • CommandLineRunner
#
# 4 Spring Boot gebruiken – Spring Data JPA
# • Snelle introductie tot ORM met JPA
# • Voordelen van het gebruik van Spring met JPA
# • JPA-configuratie in de lente
# • Spring JPA configureren met Spring Boot
# • Spring Data JPA dynamische repositories
#
# 5 webapplicaties met Spring Boot
# • Inleiding tot Spring MVC en aanvraagverwerking
# • Handtekeningen van controllermethodes
# • Gebruik van @Controller, @RestController en @GetMapping annotaties
# • Spring MVC configureren met Spring Boot
# • Spring Boot verpakkingsopties, JAR of WAR
#
# 6 RESTful Application met Spring Boot
# • Een inleiding tot de REST-architectuurstijl
# • HTTP-responscodes beheren met @ResponseStatus
# • REST implementeren met Spring MVC, @RequestMapping, @RequestBody en @ResponseBody
# • Spring MVC's HttpMessageConverters en automatische contentonderhandeling
#
# 7 Spring Boot Testing
# • Spring Boot testing overzicht
# • Integratie testen met behulp van @SpringBootTest
# • Web slice testen met MockMvc framework
# • Slices om verschillende lagen van de applicatie
#
# te testen 8 Rest-applicatie beveiligen met Spring Security
# • Welke problemen lost Spring Security op?
# • Authenticatie configureren
# • Autorisatie implementeren door URL's
# te onderscheppen • Autorisatie op Java-methodeniveau
# • Inzicht in de Spring Security-filterketen
# • Spring-beveiligingstests
#
# 9 actuatoren, metrische gegevens en gezondheidsindicatoren
# • Spring Boot Actuator-eindpunten
# blootstellen • Aangepaste statistieken • Gezondheidsindicatoren
# • Aangepaste gezondheidsindicatoren
# maken
# • Externe monitoringsystemen
